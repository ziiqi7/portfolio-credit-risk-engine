# %% [markdown]
# # Correlation Roadmap
#
# This notebook documents how the independent migration baseline can evolve into a correlated latent-factor engine.

# %% [markdown]
# ## Planned extensions
#
# - one-factor latent credit driver
# - Gaussian copula style dependence
# - sector factors
# - rating-threshold mapping from latent variables to migration states
# - tail attribution and stress overlays

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.correlation import build_rating_thresholds
from src.transitions import load_demo_transition_matrices

# %%
matrices = load_demo_transition_matrices()
corporate_thresholds = build_rating_thresholds(matrices["corporate"].matrix)
corporate_thresholds["BBB"][:4]
